# %%
import pandas as pd

# Path to your Excel file
file_path = "teams_all_matches.xlsx"

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)
world_cup_teams = [
    "Afghanistan",
    "Australia",
    "Bangladesh",
    "Canada",
    "England",
    "India",
    "Ireland",
    "Namibia",
    "Nepal",
    "Netherlands",
    "New Zealand",
    "Oman",
    "Pakistan",
    "Papua New Guinea",
    "Scotland",
    "South Africa",
    "Sri Lanka",
    "Uganda",
    "United States of America",
    "West Indies"
]

# %%
import pandas as pd

def filter_and_select(df, filter_conditions, columns_to_select):
    """
    Filters the DataFrame based on the conditions and selects specified columns.

    :param df: pandas DataFrame
    :param filter_conditions: Dictionary with column names as keys and filter values as values or lists of values
    :param columns_to_select: List of column names to select
    :return: Filtered DataFrame with selected columns
    """
    # Build the filter mask
    mask = pd.Series([True] * len(df))
    for col, val in filter_conditions.items():
        if isinstance(val, list):
            mask &= df[col].isin(val)
        else:
            mask &= (df[col] == val)
    
    # Filter the DataFrame
    filtered_df = df[mask]
    
    # Select the specified columns
    selected_columns_df = filtered_df[columns_to_select]
    
    return selected_columns_df




# Example usage with a list of teams
filter_conditions = {'Team': world_cup_teams}
columns_to_select = ['Team', '%W', 'W/L']
result_df = filter_and_select(df, filter_conditions, columns_to_select)

# Display the resulting DataFrame
print(result_df)
# Out:
#                          Team     %W    W/L
# 0                 Afghanistan  61.36  1.687
# 2                   Australia  53.92  1.271
# 6                  Bangladesh  38.59  0.653
# 16                     Canada  50.81  1.148
# 26                    England  51.61  1.185
# 41                      India  64.41  2.102
# 44                    Ireland  42.26  0.806
# 63                    Namibia  62.68  1.826
# 64                      Nepal  56.97  1.441
# 65                Netherlands  49.54  1.102
# 66                New Zealand  50.00  1.184
# 69                       Oman  48.78  1.025
# 70                   Pakistan  57.78  1.532
# 72           Papua New Guinea  55.55  1.296
# 81                   Scotland  46.93  0.978
# 87               South Africa  55.30  1.302
# 90                  Sri Lanka  44.50  0.850
# 97                     Uganda  74.46  3.333
# 99   United States of America  54.83  1.545
# 101               West Indies  43.43  0.868

# %%
import pandas as pd

result_df
# Loop through each column and print unique values
for col in df.columns:
  unique_values = df[col].unique()
  print(f"Unique values in column '{col}': {unique_values}")
# Out:
# Unique values in column 'Team': ['Afghanistan' 'Argentina' 'Australia' 'Austria' 'Bahamas' 'Bahrain'
#  'Bangladesh' 'Belgium' 'Belize' 'Bermuda' 'Bhutan' 'Botswana' 'Brazil'
#  'Bulgaria' 'Cambodia' 'Cameroon' 'Canada' 'Cayman Islands' 'Chile'
#  'China' 'Cook Islands' 'Costa Rica' 'Croatia' 'Cyprus' 'Czech Republic'
#  'Denmark' 'England' 'Estonia' 'Eswatini' 'Fiji' 'Finland' 'France'
#  'Gambia' 'Germany' 'Ghana' 'Gibraltar' 'Greece' 'Guernsey' 'Hong Kong'
#  'Hungary' 'ICC World XI' 'India' 'Indonesia' 'Iran' 'Ireland'
#  'Isle of Man' 'Israel' 'Italy' 'Japan' 'Jersey' 'Kenya' 'Kuwait'
#  'Lesotho' 'Luxembourg' 'Malawi' 'Malaysia' 'Maldives' 'Mali' 'Malta'
#  'Mexico' 'Mongolia' 'Mozambique' 'Myanmar' 'Namibia' 'Nepal'
#  'Netherlands' 'New Zealand' 'Nigeria' 'Norway' 'Oman' 'Pakistan' 'Panama'
#  'Papua New Guinea' 'Peru' 'Philippines' 'Portugal' 'Qatar' 'Romania'
#  'Rwanda' 'Samoa' 'Saudi Arabia' 'Scotland' 'Serbia' 'Seychelles'
# ...

# %%
x = result_df['Team'].unique()

# %%
# Path to your Excel file
file_path = "TeamAvsTeamB.xlsx"

# Read the Excel file into a DataFrame
df = pd.read_excel(file_path)

# %%
# Example usage with a list of teams
filter_conditions = {'Team': world_cup_teams}
columns_to_select = ['Team','Opposition', '%W']
result_df = filter_and_select(df, filter_conditions, columns_to_select)

# Display the resulting DataFrame
print(result_df)
# Out:
#              Team    Opposition      %W
# 0     Afghanistan     Australia    0.00
# 1     Afghanistan    Bangladesh   54.54
# 2     Afghanistan        Canada  100.00
# 3     Afghanistan       England    0.00
# 4     Afghanistan     Hong Kong   60.00
# ...           ...           ...     ...
# 1305  West Indies      Scotland    0.00
# 1306  West Indies  South Africa   50.00
# 1307  West Indies     Sri Lanka   46.66
# 1308  West Indies        Uganda  100.00
# 1309  West Indies      Zimbabwe   75.00
#
# [400 rows x 3 columns]

# %%
# Path to your Excel file
file_path = "teamsdata.csv"

# Read the Excel file into a DataFrame
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#          Ground     Margin Match_Date         Team1         Team2  matchID  \
# 0      Auckland    44 runs  17-Feb-05   New Zealand     Australia        1
# 1   Southampton   100 runs  13-Jun-05       England     Australia        2
# 2  Johannesburg  5 wickets  21-Oct-05  South Africa   New Zealand        3
# 3      Brisbane    95 runs   9-Jan-06     Australia  South Africa        4
# 4      Auckland          -  16-Feb-06   New Zealand   West Indies        5
#
#         winner
# 0    Australia
# 1      England
# 2  New Zealand
# 3    Australia
# 4         tied

# %%
# Example usage with a list of teams
filter_conditions = {'Team1': world_cup_teams,'Team2': world_cup_teams}
columns_to_select = ['Team1','Team2', 'winner']
result_df = filter_and_select(df, filter_conditions, columns_to_select)

# Display the resulting DataFrame
print(result_df)
# Out:
#              Team1         Team2        winner
# 0      New Zealand     Australia     Australia
# 1          England     Australia       England
# 2     South Africa   New Zealand   New Zealand
# 3        Australia  South Africa     Australia
# 4      New Zealand   West Indies          tied
# ...            ...           ...           ...
# 2629   West Indies  South Africa   West Indies
# 2630       England      Pakistan       England
# 2633       Namibia          Oman          tied
# 2634  South Africa     Sri Lanka  South Africa
# 2635   Afghanistan        Uganda   Afghanistan
#
# [1075 rows x 3 columns]

# %%
import pandas as pd

# List of World Cup teams
WORLD_CUP_TEAMS = [
    "Afghanistan", "Australia", "Bangladesh", "Canada", "England", "India",
    "Ireland", "Namibia", "Nepal", "Netherlands", "New Zealand", "Oman",
    "Pakistan", "Papua New Guinea", "Scotland", "South Africa", "Sri Lanka",
    "Uganda", "United States of America", "West Indies"
]

def read_excel_file(file_path):
    return pd.read_excel(file_path)

def read_csv_file(file_path):
    return pd.read_csv(file_path)

def filter_and_select(df, filter_conditions, columns_to_select):
    mask = pd.Series([True] * len(df))
    for col, val in filter_conditions.items():
        if isinstance(val, list):
            mask &= df[col].isin(val)
        else:
            mask &= (df[col] == val)
    
    # Filter the DataFrame
    filtered_df = df[mask]
    
    # Select the specified columns
    selected_columns_df = filtered_df[columns_to_select]
    
    return selected_columns_df

def process_teams_data(file_path, filter_conditions, columns_to_select, file_type='excel'):
    if file_type == 'excel':
        df = read_excel_file(file_path)
    elif file_type == 'csv':
        df = read_csv_file(file_path)
    else:
        raise ValueError("Invalid file type. Supported types are 'excel' and 'csv'.")
    return filter_and_select(df, filter_conditions, columns_to_select)



# Define filter conditions and columns to select
filter_conditions = {'Team': WORLD_CUP_TEAMS}
columns_to_select = ['Team', 'Mat', 'Won','Lost']

# Process first Excel file
file_path_1 = "teams_all_matches.xlsx"
team_stats_df = process_teams_data(file_path_1, filter_conditions, columns_to_select)
print(team_stats_df.head())

# # Process second Excel file
# file_path_2 = "TeamAvsTeamB.xlsx"
# filter_conditions_3 = {'Team': WORLD_CUP_TEAMS, 'Opposition': WORLD_CUP_TEAMS}
# columns_to_select_2 = ['Team', 'Opposition', '%W']
# TeamAvsTeamB = process_teams_data(file_path_2, filter_conditions_3, columns_to_select_2)
# print(TeamAvsTeamB.head())

# Process CSV file
file_path_3 = "teamsdata.csv"
filter_conditions_3 = {'Team1': WORLD_CUP_TEAMS, 'Team2': WORLD_CUP_TEAMS}
columns_to_select_3 = ['Team1', 'Team2', 'winner']
matches_df = process_teams_data(file_path_3, filter_conditions_3, columns_to_select_3, file_type='csv')
print(matches_df.head())

file_path_4 = "icc_rankings.xlsx"

filter_conditions_4 = {'Team': WORLD_CUP_TEAMS}
columns_to_select_4 = ['Team','Rank']
rank_df = process_teams_data(file_path_4, filter_conditions_4, columns_to_select_4)
print(rank_df.head())
# Out:
#            Team  Mat  Won  Lost
# 0   Afghanistan  132   81    48
# 2     Australia  191  103    81
# 6    Bangladesh  171   66   101
# 16       Canada   61   31    27
# 26      England  186   96    81
#           Team1         Team2       winner
# 0   New Zealand     Australia    Australia
# 1       England     Australia      England
# 2  South Africa   New Zealand  New Zealand
# 3     Australia  South Africa    Australia
# 4   New Zealand   West Indies         tied
#            Team  Rank
# 0         India     1
# 1     Australia     2
# 2   West Indies     3
# 3       England     4
# 4  South Africa     5

# %%
# Merge matches_df with team_stats_df for Team1
merged_df = pd.merge(teamsdata, team_stats_df, left_on='Team1', right_on='Team', how='left', suffixes=('', '_Team1'))
merged_df = merged_df.drop(columns=['Team'])

# Merge the resulting dataframe with team_stats_df for Team2
merged_df = pd.merge(merged_df, team_stats_df, left_on='Team2', right_on='Team', how='left', suffixes=('_Team1', '_Team2'))
merged_df = merged_df.drop(columns=['Team'])
merged_df.to_excel("mydata.xlsx")

# Print the final merged dataframe
print(merged_df)
# Out:
#              Team1         Team2        winner  Mat_Team1  Won_Team1  \
# 0      New Zealand     Australia     Australia        218        109
# 1          England     Australia       England        186         96
# 2     South Africa   New Zealand   New Zealand        179         99
# 3        Australia  South Africa     Australia        191        103
# 4      New Zealand   West Indies          tied        218        109
# ...            ...           ...           ...        ...        ...
# 1070   West Indies  South Africa   West Indies        198         86
# 1071       England      Pakistan       England        186         96
# 1072       Namibia          Oman          tied         67         42
# 1073  South Africa     Sri Lanka  South Africa        179         99
# 1074   Afghanistan        Uganda   Afghanistan        132         81
#
#       Lost_Team1  Mat_Team2  Won_Team2  Lost_Team2
# 0             92        191        103          81
# ...

# %%
merged_df = pd.merge(merged_df, rank_df, left_on='Team1', right_on='Team', how='left')
merged_df = merged_df.rename(columns={'Rank': 'Rank_Team1'}).drop(columns=['Team'])

# Merge the resulting dataframe with rank_df for Team2
merged_df = pd.merge(merged_df, rank_df, left_on='Team2', right_on='Team', how='left')
merged_df = merged_df.rename(columns={'Rank': 'Rank_Team2'}).drop(columns=['Team'])

# %%
merged_df.columns
# Out:
# Index(['Team1', 'Team2', 'winner', 'Mat_Team1', 'Won_Team1', 'Lost_Team1',
#        'Mat_Team2', 'Won_Team2', 'Lost_Team2', 'Rank_Team1', 'Rank_Team2'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(15, 10))
sns.heatmap(merged_df[[ 'Mat_Team1', 'Won_Team1', 'Lost_Team1',
       'Mat_Team2', 'Won_Team2', 'Lost_Team2', 'Rank_Team1', 'Rank_Team2']].corr())
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix

def train_model(X_train, y_train, model, params):
    """
    Train a model using GridSearchCV with StratifiedKFold.

    :param X_train: Training features
    :param y_train: Training labels
    :param model: The machine learning model to train
    :param params: Dictionary of hyperparameters for GridSearchCV
    :return: Best trained model
    """
    skf = StratifiedKFold(n_splits=3)
    grid_search = GridSearchCV(model, params, cv=skf, n_jobs=-1, verbose=False)
    grid_search.fit(X_train, np.ravel(y_train))
    return grid_search.best_estimator_

def analyze_model(model, X_train, X_test, y_train, y_test):
    """
    Analyze the performance of the model using ROC curve and confusion matrix.

    :param model: Trained machine learning model
    :param X_train: Training features
    :param X_test: Testing features
    :param y_train: Training labels
    :param y_test: Testing labels
    """
    # Calculate ROC curve and AUC
    fpr, tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])
    fpr_train, tpr_train, _ = roc_curve(y_train, model.predict_proba(X_train)[:, 1])
    auc_test = roc_auc_score(y_test, model.predict_proba(X_test)[:, 1])
    auc_train = roc_auc_score(y_train, model.predict_proba(X_train)[:, 1])
    
    # Plot ROC curve
    plt.figure(figsize=(15, 10))
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label="Test AUC = %.2f" % auc_test)
    plt.plot(fpr_train, tpr_train, label="Train AUC = %.2f" % auc_train)
    plt.legend()
    plt.title('ROC Curve')
    plt.show()
    
    # Plot confusion matrix
    cm = confusion_matrix(y_test, model.predict(X_test))
    plt.figure(figsize=(15, 10))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

def main():
    # Sample data for demonstration

    df = merged_df

    # Modify the winner column to 1 if Team1 wins, 0 if Team2 wins
    df['winner'] = np.where(df['winner'] == df['Team1'], 1, 0)

    # Define features and target variable
    features = ['Team1', 'Team2', 'Mat_Team1', 'Won_Team1', 'Lost_Team1', 'Mat_Team2', 'Won_Team2', 'Lost_Team2', 'Rank_Team1', 'Rank_Team2']
    target = 'winner'

    X = df[features]
    y = df[target]

    # OneHotEncoder for categorical variables
    categorical_features = ['Team1', 'Team2']
    numeric_features = ['Mat_Team1', 'Won_Team1', 'Lost_Team1', 'Mat_Team2', 'Won_Team2', 'Lost_Team2', 'Rank_Team1', 'Rank_Team2']

    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OneHotEncoder(), categorical_features),
            ('num', 'passthrough', numeric_features)
        ]
    )

    # Define the models and their hyperparameters
    gb_params = {
        "gb__learning_rate": [0.01, 0.1, 0.5],
        "gb__min_samples_split": [5, 10],
        "gb__min_samples_leaf": [3, 5],
        "gb__max_depth": [3, 5, 10],
        "gb__max_features": ["sqrt"],
        "gb__n_estimators": [100, 200]
    }

    rf_params = {
        "rf__max_depth": [20],
        "rf__min_samples_split": [10],
        "rf__max_leaf_nodes": [175],
        "rf__min_samples_leaf": [5],
        "rf__n_estimators": [250],
        "rf__max_features": ["sqrt"]
    }

    # Pipelines for Gradient Boosting and Random Forest
    gb_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('gb', GradientBoostingClassifier(random_state=5))
    ])

    rf_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('rf', RandomForestClassifier(random_state=1))
    ])

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

    # Train Gradient Boosting and Random Forest models
    gb_model = train_model(X_train, y_train, gb_pipeline, gb_params)
    rf_model = train_model(X_train, y_train, rf_pipeline, rf_params)

    # Analyze models
    print("Gradient Boosting Model Analysis:")
    analyze_model(gb_model, X_train, X_test, y_train, y_test)
    print("\nRandom Forest Model Analysis:")
    analyze_model(rf_model, X_train, X_test, y_train, y_test)

if __name__ == "__main__":
    main()
# Out:
# C:\Users\manoj\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   warnings.warn(
# C:\Users\manoj\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [nan]
#   warnings.warn(
# Gradient Boosting Model Analysis:
# Random Forest Model Analysis:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Assuming df is your DataFrame (merged_df in this case)
df = merged_df.copy()

# Modify the winner column to 1 if Team1 wins, 0 if Team2 wins
df['winner'] = np.where(df['winner'] == df['Team1'], 1, 
                        np.where(df['winner'] == df['Team2'], 0, df['winner']))

# Count the number of 0 and 1 values in y
winner_counts = df['winner'].value_counts()
print(f"Counts of 0 and 1 in the target variable 'winner':\n{winner_counts}")

# Plot the values of 0 and 1
winner_counts.plot(kind='bar', color=['blue', 'orange'])
plt.xlabel('Winner')
plt.ylabel('Counts')
plt.title('Counts of 0 and 1 in the target variable "winner"')
plt.xticks([0, 1], ['Team2 Wins', 'Team1 Wins'], rotation=0)
plt.show()
# Out:
# Counts of 0 and 1 in the target variable 'winner':
# winner
# 0    544
# 1    531
# Name: count, dtype: int64

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, accuracy_score

def train_model(X_train, y_train, model, params):
    """
    Train a model using GridSearchCV with StratifiedKFold.

    :param X_train: Training features
    :param y_train: Training labels
    :param model: The machine learning model to train
    :param params: Dictionary of hyperparameters for GridSearchCV
    :return: Best trained model
    """
    skf = StratifiedKFold(n_splits=3)
    grid_search = GridSearchCV(model, params, cv=skf, n_jobs=-1, verbose=True, error_score='raise')
    grid_search.fit(X_train, np.ravel(y_train))
    return grid_search.best_estimator_

def analyze_model(model, X_train, X_test, y_train, y_test):
    """
    Analyze the performance of the model using ROC curve, confusion matrix, and accuracy.

    :param model: Trained machine learning model
    :param X_train: Training features
    :param X_test: Testing features
    :param y_train: Training labels
    :param y_test: Testing labels
    """
    # Predict probabilities and calculate ROC curve and AUC
    y_test_proba = model.predict_proba(X_test)[:, 1]
    y_train_proba = model.predict_proba(X_train)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_test_proba)
    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_proba)
    auc_test = roc_auc_score(y_test, y_test_proba)
    auc_train = roc_auc_score(y_train, y_train_proba)
    
    # Plot ROC curve
    plt.figure(figsize=(15, 10))
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label="Test AUC = %.2f" % auc_test)
    plt.plot(fpr_train, tpr_train, label="Train AUC = %.2f" % auc_train)
    plt.legend()
    plt.title('ROC Curve')
    plt.show()
    
    # Plot confusion matrix
    cm = confusion_matrix(y_test, model.predict(X_test))
    plt.figure(figsize=(15, 10))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    
    # Calculate and print accuracy
    train_accuracy = accuracy_score(y_train, model.predict(X_train))
    test_accuracy = accuracy_score(y_test, model.predict(X_test))
    print(f"Train Accuracy: {train_accuracy:.2f}")
    print(f"Test Accuracy: {test_accuracy:.2f}")

def main():
    df = merged_df.copy()

    # Modify the winner column to 1 if Team1 wins, 0 if Team2 wins
    df['winner'] = np.where(df['winner'] == df['Team1'], 1, 
                            np.where(df['winner'] == df['Team2'], 0, df['winner']))
    # Define features and target variable
    features = ['Team1', 'Team2', 'Mat_Team1', 'Won_Team1', 'Lost_Team1', 'Mat_Team2', 'Won_Team2', 'Lost_Team2', 'Rank_Team1', 'Rank_Team2']
    target = 'winner'

    X = df[features]
    y = df[target]

    # OneHotEncoder for categorical variables
    categorical_features = ['Team1', 'Team2']
    numeric_features = ['Mat_Team1', 'Won_Team1', 'Lost_Team1', 'Mat_Team2', 'Won_Team2', 'Lost_Team2', 'Rank_Team1', 'Rank_Team2']

    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
            ('num', 'passthrough', numeric_features)
        ]
    )

    # Define the models and their hyperparameters
    gb_params = {
        "gb__learning_rate": [0.01, 0.1],
        "gb__min_samples_split": [5, 10],
        "gb__min_samples_leaf": [3, 5],
        "gb__max_depth": [3, 5],
        "gb__max_features": ["sqrt"],
        "gb__n_estimators": [100, 200]
    }

    rf_params = {
        "rf__max_depth": [20],
        "rf__min_samples_split": [10],
        "rf__max_leaf_nodes": [175],
        "rf__min_samples_leaf": [5],
        "rf__n_estimators": [100, 200],
        "rf__max_features": ["sqrt"]
    }

    # Pipelines for Gradient Boosting and Random Forest
    gb_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('gb', GradientBoostingClassifier(random_state=5))
    ])

    rf_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('rf', RandomForestClassifier(random_state=1))
    ])

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1, stratify=y)

    # Train Gradient Boosting and Random Forest models
    gb_model = train_model(X_train, y_train, gb_pipeline, gb_params)
    rf_model = train_model(X_train, y_train, rf_pipeline, rf_params)

    # Analyze models
    print("Gradient Boosting Model Analysis:")
    analyze_model(gb_model, X_train, X_test, y_train, y_test)
    print("\nRandom Forest Model Analysis:")
    analyze_model(rf_model, X_train, X_test, y_train, y_test)

if __name__ == "___main__":
    main()

# %%
main()
# Out:
# Fitting 3 folds for each of 32 candidates, totalling 96 fits
# Fitting 3 folds for each of 2 candidates, totalling 6 fits
# Gradient Boosting Model Analysis:
# Train Accuracy: 0.66
# Test Accuracy: 0.58
#
# Random Forest Model Analysis:
# Train Accuracy: 0.67
# Test Accuracy: 0.59

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.metrics import roc_curve, roc_auc_score, confusion_matrix, accuracy_score
from xgboost import XGBClassifier

def train_model(X_train, y_train, model, params):
    """
    Train a model using GridSearchCV with StratifiedKFold.

    :param X_train: Training features
    :param y_train: Training labels
    :param model: The machine learning model to train
    :param params: Dictionary of hyperparameters for GridSearchCV
    :return: Best trained model
    """
    skf = StratifiedKFold(n_splits=5)
    grid_search = GridSearchCV(model, params, cv=skf, n_jobs=-1, verbose=True, error_score='raise')
    grid_search.fit(X_train, np.ravel(y_train))
    return grid_search.best_estimator_

def analyze_model(model, X_train, X_test, y_train, y_test):
    """
    Analyze the performance of the model using ROC curve, confusion matrix, and accuracy.

    :param model: Trained machine learning model
    :param X_train: Training features
    :param X_test: Testing features
    :param y_train: Training labels
    :param y_test: Testing labels
    """
    # Predict probabilities and calculate ROC curve and AUC
    y_test_proba = model.predict_proba(X_test)[:, 1]
    y_train_proba = model.predict_proba(X_train)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_test_proba)
    fpr_train, tpr_train, _ = roc_curve(y_train, y_train_proba)
    auc_test = roc_auc_score(y_test, y_test_proba)
    auc_train = roc_auc_score(y_train, y_train_proba)
    
    # Plot ROC curve
    plt.figure(figsize=(15, 10))
    plt.plot([0, 1], [0, 1], 'k--')
    plt.plot(fpr, tpr, label="Test AUC = %.2f" % auc_test)
    plt.plot(fpr_train, tpr_train, label="Train AUC = %.2f" % auc_train)
    plt.legend()
    plt.title('ROC Curve')
    plt.show()
    
    # Plot confusion matrix
    cm = confusion_matrix(y_test, model.predict(X_test))
    plt.figure(figsize=(15, 10))
    sns.heatmap(cm, annot=True, fmt="d", cmap='Blues')
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()
    
    # Calculate and print accuracy
    train_accuracy = accuracy_score(y_train, model.predict(X_train))
    test_accuracy = accuracy_score(y_test, model.predict(X_test))
    print(f"Train Accuracy: {train_accuracy:.2f}")
    print(f"Test Accuracy: {test_accuracy:.2f}")

def main():
    # Sample data for demonstration
    df = merged_df.copy()

    # Modify the winner column to 1 if Team1 wins, 0 if Team2 wins
    df['winner'] = np.where(df['winner'] == df['Team1'], 1, 
                            np.where(df['winner'] == df['Team2'], 0, df['winner']))

    # Feature Engineering
    df['Rank_Diff'] = df['Rank_Team1'] - df['Rank_Team2']
    df['Win_Ratio_Team1'] = df['Won_Team1'] / (df['Won_Team1'] + df['Lost_Team1'])
    df['Win_Ratio_Team2'] = df['Won_Team2'] / (df['Won_Team2'] + df['Lost_Team2'])

    # Check class distribution
    print(df['winner'].value_counts())

    # Define features and target variable
    features = ['Team1', 'Team2', 'Mat_Team1', 'Win_Ratio_Team1', 'Mat_Team2', 'Win_Ratio_Team2', 'Rank_Team1', 'Rank_Team2', 'Rank_Diff']
    target = 'winner'

    X = df[features]
    y = df[target]

    # OneHotEncoder for categorical variables with handle_unknown='ignore'
    categorical_features = ['Team1', 'Team2']
    numeric_features = ['Mat_Team1', 'Win_Ratio_Team1', 'Mat_Team2', 'Win_Ratio_Team2', 'Rank_Team1', 'Rank_Team2', 'Rank_Diff']

    preprocessor = ColumnTransformer(
        transformers=[
            ('cat', OneHotEncoder(handle_unknown='ignore'), categorical_features),
            ('num', 'passthrough', numeric_features)
        ]
    )

    # Define the models and their hyperparameters
    gb_params = {
        "gb__learning_rate": [0.01, 0.1, 0.3],
        "gb__min_samples_split": [5, 10, 15],
        "gb__min_samples_leaf": [3, 5, 10],
        "gb__max_depth": [3, 5, 10],
        "gb__max_features": ["sqrt", "log2"],
        "gb__n_estimators": [100, 200, 300]
    }

    rf_params = {
        "rf__max_depth": [10, 20, 30],
        "rf__min_samples_split": [2, 10, 20],
        "rf__max_leaf_nodes": [50, 100, 200],
        "rf__min_samples_leaf": [1, 5, 10],
        "rf__n_estimators": [100, 200, 300],
        "rf__max_features": ["sqrt", "log2"]
    }

    xgb_params = {
        "xgb__learning_rate": [0.01, 0.1, 0.3],
        "xgb__max_depth": [3, 5, 10],
        "xgb__n_estimators": [100, 200, 300],
        "xgb__subsample": [0.7, 0.8, 1.0],
        "xgb__colsample_bytree": [0.7, 0.8, 1.0]
    }

    # Pipelines for Gradient Boosting, Random Forest, and XGBoost
    gb_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('gb', GradientBoostingClassifier(random_state=5))
    ])

    rf_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('rf', RandomForestClassifier(random_state=1))
    ])

    xgb_pipeline = Pipeline([
        ('preprocessor', preprocessor),
        ('xgb', XGBClassifier(random_state=1, use_label_encoder=False, eval_metric='logloss'))
    ])

    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1, stratify=y)

    # Train Gradient Boosting, Random Forest, and XGBoost models
    gb_model = train_model(X_train, y_train, gb_pipeline, gb_params)
    rf_model = train_model(X_train, y_train, rf_pipeline, rf_params)
    xgb_model = train_model(X_train, y_train, xgb_pipeline, xgb_params)

    # Analyze models
    print("Gradient Boosting Model Analysis:")
    analyze_model(gb_model, X_train, X_test, y_train, y_test)
    print("\nRandom Forest Model Analysis:")
    analyze_model(rf_model, X_train, X_test, y_train, y_test)
    print("\nXGBoost Model Analysis:")
    analyze_model(xgb_model, X_train, X_test, y_train, y_test)

if __name__ == "__main__":
    main()
# Out:
# winner
# 0    544
# 1    531
# Name: count, dtype: int64
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Fitting 5 folds for each of 486 candidates, totalling 2430 fits
# Fitting 5 folds for each of 243 candidates, totalling 1215 fits
# exception calling callback for <Future at 0x2238ceeabd0 state=finished returned list>
# Traceback (most recent call last):
#   File "C:\Users\manoj\anaconda3\Lib\site-packages\joblib\externals\loky\_base.py", line 26, in _invoke_callbacks
#     callback(self)
#   File "C:\Users\manoj\anaconda3\Lib\site-packages\joblib\parallel.py", line 385, in __call__
#     self.parallel.dispatch_next()
#   File "C:\Users\manoj\anaconda3\Lib\site-packages\joblib\parallel.py", line 834, in dispatch_next
#     if not self.dispatch_one_batch(self._original_iterator):
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\manoj\anaconda3\Lib\site-packages\joblib\parallel.py", line 901, in dispatch_one_batch
# ...
